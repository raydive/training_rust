// %%
let mut num = 5;
let r1 = &num as *const i32;
let r2 = &mut num as *mut i32;

unsafe {
    println!("r1 is: {}", *r1);
    println!("r2 is: {}", *r2);
}
// Out:
// r1 is: 5
// r2 is: 5
// ()

// %%
let mut num = 5;
let r1 = &num as *const i32;
let r2 = &mut num as *mut i32;

println!("r1 is: {}", *r1);
println!("r2 is: {}", *r2);
// Out:
// [E0133] Error: dereference of raw pointer is unsafe and requires unsafe function or block
//    ╭─[command_3:1:1]
//    │
//  5 │ println!("r1 is: {}", *r1);
//    ·                       ─┬─
//    ·                        ╰─── dereference of raw pointer
// ───╯
// [E0133] Error: dereference of raw pointer is unsafe and requires unsafe function or block
//    ╭─[command_3:1:1]
//    │
//  6 │ println!("r2 is: {}", *r2);
//    ·                       ─┬─
//    ·                        ╰─── dereference of raw pointer
// ───╯

// %%
unsafe fn test() {}

unsafe {
    test();
}
// Out:
// ()

// %%
unsafe fn test() {}

test();
// Out:
// [E0133] Error: call to unsafe function `test` is unsafe and requires unsafe function or block
//    ╭─[command_5:1:1]
//    │
//  3 │ test();
//    · ───┬──
//    ·    ╰──── call to unsafe function
// ───╯
